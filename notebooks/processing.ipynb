# %%
from transformers import (
    AutoTokenizer,
)
from trl import (
    SFTTrainer,
    AutoModelForCausalLMWithValueHead,
    PPOConfig,
    PPOTrainer,
)
from peft import LoraConfig
import os

# %%
tokenizer = AutoTokenizer.from_pretrained("meta-llama/Meta-Llama-3.1-8B-Instruct")
tokenizer.tokenize(    
    {
        "role": "user",
        "content": "A proposal has been made by the other player. Using the <reason> tag, remember the division that was agreed upon and then make a final proposal using the <propose> tag, describing the division of items you agreed upon, no items should be left over. The proposal should be formatted has <propose>{ \"i_take\": {\"books\":x, \"hats\":y, \"balls\":z}, \"other_player_gets\": {\"books\":a, \"hats\":b, \"balls\":c} }</propose>, where 'i_take' is your share and 'other_player_gets' is your partner share of the items.",
        "is_error": False,
        "is_new_round": False
    })
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 tokenizer = AutoTokenizer.from_pretrained("meta-llama/Meta-Llama-3.1-8B-Instruct")
# ----> 2 tokenizer.tokenize(
#       3     {
#       4         "role": "user",
#       5         "content": "A proposal has been made by the other player. Using the <reason> tag, remember the division that was agreed upon and then make a final proposal using the <propose> tag, describing the division of items you agreed upon, no items should be left over. The proposal should be formatted has <propose>{ \"i_take\": {\"books\":x, \"hats\":y, \"balls\":z}, \"other_player_gets\": {\"books\":a, \"hats\":b, \"balls\":c} }</propose>, where 'i_take' is your share and 'other_player_gets' is your partner share of the items.",
#       6         "is_error": False,
#       7         "is_new_round": False
#       8     })
#
# File ~/negenv/lib/python3.10/site-packages/transformers/tokenization_utils_fast.py:416, in PreTrainedTokenizerFast.tokenize(self, text, pair, add_special_tokens, **kwargs)
#     415 def tokenize(self, text: str, pair: Optional[str] = None, add_special_tokens: bool = False, **kwargs) -> List[str]:
# --> 416     return self.encode_plus(text=text, text_pair=pair, add_special_tokens=add_special_tokens, **kwargs).tokens()
#
# File ~/negenv/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:3255, in PreTrainedTokenizerBase.encode_plus(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    3245 # Backward compatibility for 'truncation_strategy', 'pad_to_max_length'
#    3246 padding_strategy, truncation_strategy, max_length, kwargs = self._get_padding_truncation_strategies(
#    3247     padding=padding,
#    3248     truncation=truncation,
#    (...)
#    3252     **kwargs,
#    3253 )
# -> 3255 return self._encode_plus(
#    3256     text=text,
#    3257     text_pair=text_pair,
#    3258     add_special_tokens=add_special_tokens,
#    3259     padding_strategy=padding_strategy,
#    3260     truncation_strategy=truncation_strategy,
#    3261     max_length=max_length,
#    3262     stride=stride,
#    3263     is_split_into_words=is_split_into_words,
#    3264     pad_to_multiple_of=pad_to_multiple_of,
#    3265     return_tensors=return_tensors,
#    3266     return_token_type_ids=return_token_type_ids,
#    3267     return_attention_mask=return_attention_mask,
#    3268     return_overflowing_tokens=return_overflowing_tokens,
#    3269     return_special_tokens_mask=return_special_tokens_mask,
#    3270     return_offsets_mapping=return_offsets_mapping,
#    3271     return_length=return_length,
#    3272     verbose=verbose,
#    3273     split_special_tokens=kwargs.pop("split_special_tokens", self.split_special_tokens),
#    3274     **kwargs,
#    3275 )
#
# File ~/negenv/lib/python3.10/site-packages/transformers/tokenization_utils_fast.py:601, in PreTrainedTokenizerFast._encode_plus(self, text, text_pair, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens, **kwargs)
#     578 def _encode_plus(
#     579     self,
#     580     text: Union[TextInput, PreTokenizedInput],
#    (...)
#     598     **kwargs,
#     599 ) -> BatchEncoding:
#     600     batched_input = [(text, text_pair)] if text_pair else [text]
# --> 601     batched_output = self._batch_encode_plus(
#     602         batched_input,
#     603         is_split_into_words=is_split_into_words,
#     604         add_special_tokens=add_special_tokens,
#     605         padding_strategy=padding_strategy,
#     606         truncation_strategy=truncation_strategy,
#     607         max_length=max_length,
#     608         stride=stride,
#     609         pad_to_multiple_of=pad_to_multiple_of,
#     610         return_tensors=return_tensors,
#     611         return_token_type_ids=return_token_type_ids,
#     612         return_attention_mask=return_attention_mask,
#     613         return_overflowing_tokens=return_overflowing_tokens,
#     614         return_special_tokens_mask=return_special_tokens_mask,
#     615         return_offsets_mapping=return_offsets_mapping,
#     616         return_length=return_length,
#     617         verbose=verbose,
#     618         split_special_tokens=split_special_tokens,
#     619         **kwargs,
#     620     )
#     622     # Return tensor is None, then we can remove the leading batch axis
#     623     # Overflowing tokens are returned as a batch of output so we keep them in this case
#     624     if return_tensors is None and not return_overflowing_tokens:
#
# File ~/negenv/lib/python3.10/site-packages/transformers/tokenization_utils_fast.py:528, in PreTrainedTokenizerFast._batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens)
#     525 if self._tokenizer.encode_special_tokens != split_special_tokens:
#     526     self._tokenizer.encode_special_tokens = split_special_tokens
# --> 528 encodings = self._tokenizer.encode_batch(
#     529     batch_text_or_text_pairs,
#     530     add_special_tokens=add_special_tokens,
#     531     is_pretokenized=is_split_into_words,
#     532 )
#     534 # Convert encoding to dict
#     535 # `Tokens` has type: Tuple[
#     536 #                       List[Dict[str, List[List[int]]]] or List[Dict[str, 2D-Tensor]],
#     537 #                       List[EncodingFast]
#     538 #                    ]
#     539 # with nested dimensions corresponding to batch, overflows, sequence length
#     540 tokens_and_encodings = [
#     541     self._convert_encoding(
#     542         encoding=encoding,
#    (...)
#     551     for encoding in encodings
#     552 ]
#
# TypeError: TextEncodeInput must be Union[TextInputSequence, Tuple[InputSequence, InputSequence]]
