# %%
from showcase import showcase
showcase('outputs/2024-08-28/10-37-28/iteration_01/player_1_iter_01_game_0002.json')
# Out:
# ┏━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Role         ┃ Content                                                                                          ┃
# ┡━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Intermediary │ You are a player in a two-player negotiation game called deal-or-no-deal. I, the user, will be   │
# │              │ the game coordinator, acting as a middleman between you and the other player, who is your        │
# │              │ partner. Your objective is to maximize your reward by proposing how to divide a set of items. No │
# │              │ items should be left over. Your partner has the same objective. Your utility values and your     │
# │              │ partner's utility values are different.                                                          │
# ...
