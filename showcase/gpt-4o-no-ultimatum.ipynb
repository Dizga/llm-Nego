# %%
from showcase import showcase
print("Here, we can see the first player does not play the ultimatum in the semi-competitive scenario. Both players instead reach the maximum sum of rewards.")
showcase('showcase/data/gpt-4o-no-ultimatum/iteration_01/player_0_iter_01_game_0001.json')
# Out:
# Here, we can see the first player does not play the ultimatum in the semi-competitive scenario. Both players instead reach the maximum sum of rewards.
# ┏━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                ┃                                                                                                ┃
# ┃      Role      ┃  Content                                                                                       ┃
# ┃                ┃                                                                                                ┃
# ┡━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │                │                                                                                                │
# │  Intermediary  │  You will be playing 1 rounds of a game called deal-or-no-deal.                                │
# ...
